# %% [markdown]
# This can be done by running this command on the SMuRF server:

# %% [raw]
# rfsochammer

# %% [markdown]
# You need to run this in a terminal with X-windows so the server gui can come up.  I typically do this in a VNC session.  On the SMuRF server you can check if a VNC session is running on the command line like this:

# %% [raw]
# vncryo@smurf-srv06:~$ vncserver -list
#
# TigerVNC server sessions:
#
# X DISPLAY #	PROCESS ID
# :2		20149

# %% [markdown]
# This means there's a server up and running on the SMuRF server port 5902, which is the default port I usually start VNC sessions on.  If you don't see any VNC servers up, you can start it by ssh'ing to the machine and entering this command on the command line to start a server on port 5902:

# %% [raw]
# vncserver :2 -geometry 1920x1200 -alwaysshared -localhost yes

# %% [markdown]
# Once the VNC server is up, you can forward this port from the SMuRF server to your machine via ssh like this:

# %% [raw]
# ssh -L 5902:localhost:5902 cryo@smurf-srv06

# %% [markdown]
# After which you should be able to connect to the VNC server using your viewer by pointing your viewer at `localhost:5902`.

# %% [markdown]
# If you've just run the `rfsochammer` command in the VNC session, when it completes, you should get handed a `pysmurf` session in the terminal you ran `rfsochammer` from, and the server gui should pop up in the VNC session, which looks like this:

# %% [markdown]
# ![Screen%20Shot%202023-05-18%20at%201.47.52%20PM.png](attachment:Screen%20Shot%202023-05-18%20at%201.47.52%20PM.png)

# %% [markdown]
# Currently, `rfsochammer` is configured to just start the server and client dockers, but not to do anything else (like run `setDefaults`.  From here, you can either continue to interface with the system through the pysmurf session that comes up in the terminal you ran `rfsochammer` in, or can control it through a jupyter notebook interface like I'm doing here.

# %% [markdown]
# The SMuRF server should start in a docker called `smurf_server_s3`.  Here's what it should look like if it started successfully (you can see this by running `docker logs smurf_server_s3` in a terminal session running outside the dockers on the SMuRF server):

# %% [raw]
# cryo@smurf-srv06:~/docker/pysmurf/dev/v7.2.0_rfsoc/pysmurf/scratch/shawn$ docker logs smurf_server_s3
# IP address was defined. Ignoring shelfmanager and slot number.
# FW version checking and HW type auto  detection disabled.
#
# Looking for pyrogue zip file...                   Pyrogue zip file found: '/tmp/fw/rogue_MicrowaveMuxBpEthGen2_v1.1.0_rfsoc.zip'.
# Check firmware disabled.
# Auto-detection of presence, type and version of AMC boards disabled.
# Auto-detection of type and version of AMC carrier board disabled.
#
# Staring the server using Ethernet communication...
# /usr/local/src/pysmurf/server_scripts/cmb_eth.py -g -w smurf_server_s3 -d /tmp/fw/defaults_rfsoc_zcu208.yml -e smurf_server_s3 -a 10.0.1.103 -z /tmp/fw/rogue_MicrowaveMuxBpEthGen2_v1.1.0_rfsoc.zip
# Rogue/pyrogue version v4.11.10. https://github.com/slaclab/rogue
# smurf package imported
# Valid zip file '/tmp/fw/rogue_MicrowaveMuxBpEthGen2_v1.1.0_rfsoc.zip'.
#
# Trying to ping the FPGA...
#     FPGA is online
#
# Setting up the RSSI PCIe card...
#   - PCIe for RSSI present in the system    : No
#   - PCIe for Data present in the system    : No
#   - PCIe based communication selected      : No
# Transmitter thread started...
# Starting EPICS server using prefix "smurf_server_s3"
# Enabling stream data on PVs (buffer size = 524288 points, data type = Int16)
# start: Started zmqServer on port 9006
#
# FPGA image build information:
# ===================================
# BuildStamp              : MicrowaveMuxZcu208: Vivado v2022.2, rdsrv402 (Ubuntu 20.04.6 LTS), Built Wed 10 May 2023 12:45:07 PM PDT by ruckman
# FPGA Version            : 0x1020000
# Git hash                : 0x3c8e6611e6f862998a68760800ae4138e4c98f1a
#
# Starting GUI...
#
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-cryo'
# ZmqClient::setTimeout: Setting timeout to 1000 msecs, waitRetry = 1
# Connected to AMCc at localhost:9006
# Running GUI. Close window, hit cntrl-c or send SIGTERM to 13 to exit.

# %% [markdown]
# # Starting a pysmurf instance

# %% [markdown]
# If the SMuRF server is up, you can create a pysmurf control instance like this (I'm also loading some dependencies we often use):

# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
import yaml
import time
import pickle as pkl
import os
import numpy as np
from matplotlib import cm
from scipy.signal import welch,periodogram
import pandas as pd
import glob
from scipy.optimize import curve_fit
from scipy import signal

import pysmurf.client
import matplotlib.pylab as plt
import numpy as np
import sys
import os
epics_prefix="smurf_server_s3"
config_file=os.path.abspath("/usr/local/src/pysmurf/cfg_files/lab1/experiment_lab1_rfsoc.cfg")
S = pysmurf.client.SmurfControl(epics_root=epics_prefix,cfg_file=config_file,setup=False,make_logfile=False,shelf_manager="shm-smrf-sp01")
# Out:
# [ 2024-10-04 00:08:35 ]  ERROR : band 0 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-10-04 00:08:35 ]  ERROR : band 1 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-10-04 00:08:35 ]  ERROR : band 2 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-10-04 00:08:35 ]  ERROR : band 3 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-10-04 00:08:35 ]  ERROR : band 4 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-10-04 00:08:35 ]  ERROR : band 5 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-10-04 00:08:35 ]  ERROR : band 6 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-10-04 00:08:35 ]  ERROR : band 7 is present in pysmurf cfg file, but its bay is not enabled!

# %% [markdown]
# We'll interact with the system through this `S` object from here on.

# %% [markdown]
# # Dumping versions

# %% [markdown]
# What versions of everything are we running?  This is useful to do at the top of any notebook to track what versions were used:

# %%
pysmurf.__version__
# Out:
# '8.0.0-rc3+12.gc1067044.dirty'

# %% [markdown]
# What pysmurf branch are we running?

# %%
# !git branch
# Out:
# * (HEAD detached from v8.0.0-rc3)
#   zcu208-devel

# %%
S._caget(f'{epics_prefix}:AMCc:RogueVersion', as_string=True)
# Out:
# 'v4.11.11'

# %%
S._caget(f'{epics_prefix}:AMCc:SmurfApplication:SmurfVersion', as_string=True)
# Out:
# '8.0.0-rc3+12.gc1067044'

# %%
S._caget(f'{epics_prefix}:AMCc:SmurfApplication:StartupArguments', as_string=True)
# Out:
# '-g -w smurf_server_s3 -l 1 -d /tmp/fw/smurf_cfg/defaults/defaults_rfsoc_zcu208.yml -e smurf_server_s3 --disable-bay0 --disable-bay1 -a 10.0.1.103'

# %%
S.get_fpga_git_hash_short()
# Out:
# 'e54bbcc'

# %% [markdown]
# # Power cal

# %% [markdown]
# Read the ADC:

# %% [markdown]
# First putting out a tone at 4.250 GHz nominal (not locked, synthesizer is broken), -36 dBm.

# %%
for pdBm in [-36,-30,-24,-18,-12,-6,0,3,6]:
    print(f'Set to {pdBm} dBm!')
    input()
    adcdata=S.read_adc_data(data_length=2**16, band=0, make_plot=True, show_plot=True)
    plt.figure()
    plt.plot(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2))
    plt.plot(np.real(adcdata))
    plt.plot(np.imag(adcdata))
    print(np.mean(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2)))
    plt.xlim(0,1000)
# Out:
# Set to -36 dBm!
# [ 2024-10-04 00:21:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 65536
# [ 2024-10-04 00:21:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2024-10-04 00:21:33 ]  ADC plot saved to /data/smurf_data/20241004/1728000515/plots/1728001292_adc0.png
# [ 2024-10-04 00:21:33 ]  Saving raw adc data to /data/smurf_data/20241004/1728000515/outputs/1728001292_adc0
# 78.71190330672628
# Set to -30 dBm!
# [ 2024-10-04 00:21:50 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 65536
# [ 2024-10-04 00:21:50 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2024-10-04 00:21:51 ]  ADC plot saved to /data/smurf_data/20241004/1728000515/plots/1728001311_adc0.png
# [ 2024-10-04 00:21:51 ]  Saving raw adc data to /data/smurf_data/20241004/1728000515/outputs/1728001311_adc0
# 156.39419903084732
# Set to -24 dBm!
# ...

# %%
for pdBm in [9,12,15,18]:
    print(f'Set to {pdBm} dBm!')
    input()
    adcdata=S.read_adc_data(data_length=2**16, band=0, make_plot=True, show_plot=True)
    plt.figure()
    plt.plot(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2))
    plt.plot(np.real(adcdata))
    plt.plot(np.imag(adcdata))
    print(np.mean(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2)))
    plt.xlim(0,1000)
# Out:
# Set to 9 dBm!
# [ 2024-10-04 00:25:02 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 65536
# [ 2024-10-04 00:25:02 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2024-10-04 00:25:04 ]  ADC plot saved to /data/smurf_data/20241004/1728000515/plots/1728001503_adc0.png
# [ 2024-10-04 00:25:04 ]  Saving raw adc data to /data/smurf_data/20241004/1728000515/outputs/1728001503_adc0
# 13904.076301149938
# Set to 12 dBm!
# [ 2024-10-04 00:25:20 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 65536
# [ 2024-10-04 00:25:20 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2024-10-04 00:25:22 ]  ADC plot saved to /data/smurf_data/20241004/1728000515/plots/1728001521_adc0.png
# [ 2024-10-04 00:25:22 ]  Saving raw adc data to /data/smurf_data/20241004/1728000515/outputs/1728001521_adc0
# 17899.233286818395
# Set to 15 dBm!
# ...

# %%
# back to -30dBm
adcdata=S.read_adc_data(data_length=2**16, band=0, make_plot=True, show_plot=True)
plt.figure()
plt.plot(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2))
plt.plot(np.real(adcdata))
plt.plot(np.imag(adcdata))
print(np.mean(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2)))
plt.xlim(0,1000)
# Out:
# [ 2024-10-04 00:27:02 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 65536
# [ 2024-10-04 00:27:02 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2024-10-04 00:27:03 ]  ADC plot saved to /data/smurf_data/20241004/1728000515/plots/1728001623_adc0.png
# [ 2024-10-04 00:27:03 ]  Saving raw adc data to /data/smurf_data/20241004/1728000515/outputs/1728001623_adc0
# 156.38359546800618
# (0, 1000)

# %%
plt.plot(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2))
print(np.mean(np.sqrt(np.real(adcdata)**2+np.imag(adcdata)**2)))
plt.xlim(0,1000)
# Out:
# 78.74713441044412
# (0, 1000)

# %% [markdown]
# To turn off playing the loaded tone file, can do this:

# %%
S.set_waveform_select(1,0)
