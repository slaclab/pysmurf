# %%
pip install pyvisa-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyvisa-py
#   Obtaining dependency information for pyvisa-py from https://files.pythonhosted.org/packages/70/7b/9c9cbb09596d00a3a5b009559e9b859ac459d01611fea6b3b655f74dc323/PyVISA_py-0.7.2-py3-none-any.whl.metadata
#   Downloading PyVISA_py-0.7.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyvisa>=1.13.0 (from pyvisa-py)
#   Obtaining dependency information for pyvisa>=1.13.0 from https://files.pythonhosted.org/packages/99/a0/0e739df84e0fc61abecc6b4b70ad7aea7f5d7ee37ec504baa365c0fec9da/PyVISA-1.14.1-py3-none-any.whl.metadata
#   Downloading PyVISA-1.14.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from pyvisa-py) (4.6.2)
# Downloading PyVISA_py-0.7.2-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 15.0 MB/s eta 0:00:00
# Downloading PyVISA-1.14.1-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.7/176.7 kB 42.6 MB/s eta 0:00:00
# Installing collected packages: pyvisa, pyvisa-py
#   WARNING: The scripts pyvisa-info and pyvisa-shell are installed in '/home/cryo/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pyvisa-1.14.1 pyvisa-py-0.7.2
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys 
print("running...")
import numpy as np
print('imported numpy')
#import serial 
#print('imported serial')
import time
import matplotlib
matplotlib.use('module://matplotlib_inline.backend_inline')
import matplotlib.pylab as plt
import pyvisa
# Out:
# running...
# imported numpy

# %%
rm = pyvisa.ResourceManager()
resources = rm.list_resources()
#led_driver = rm.open_resource('/dev/usbtmc0')

# Example: Query the device
#response = led_driver.query('*IDN?')
#print(response)
print(resources)
# Out:
# ()
# /home/cryo/.local/lib/python3.8/site-packages/pyvisa_py/tcpip.py:122: UserWarning: TCPIP::hislip resource discovery requires the zeroconf package to be installed... try 'pip install zeroconf'
#   warnings.warn(

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement python-usbtm (from versions: none)
# ERROR: No matching distribution found for python-usbtm
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
