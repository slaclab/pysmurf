# %% [markdown]
# # Imports

# %% [markdown]
# Repeating attempt to measure noise on UFM using RFSoC!

# %% [markdown]
# ## shawnhammer startup

# %% [markdown]
# Started up by running `rfsochammer` in a terminal. Running on slot 3, rogue version /home/cryo/docker/smurf/stable/v8.0.0-rc3_rfsoc, and experiment.cfg cfg_files/b33/experiment_b33_rfc1-2_C05-40_s4_lbOnlyBay0_fiber
# .cfg. `pysmurf` docker  /home/cryo/docker/pysmurf/dev/v8.0.0-rc3_rfsoc, tag v8.0.0-rc3 but with zcu208-devel merged into it.  `setup()`.  DR MXC is being servo'd to 100mK.
#
# Locked to external timing system via fiber.

# %% [markdown]
# Rogue server configured to use PCIe card.  Running PCIe card software driver version 5.19.3, PCIe card firmware version d89c87b6b29ddc5dab8a3be374e749725d598399.

# %% [markdown]
# ## Load, check, and record configuration

# %% [markdown]
# RFSoC

# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
import yaml
import time
import pickle as pkl
import os
import numpy as np
from matplotlib import cm
from scipy.signal import welch,periodogram
import pandas as pd
import glob
from scipy.optimize import curve_fit
from scipy import signal

import pysmurf.client
import matplotlib.pylab as plt
import numpy as np
import sys
import os
epics_prefix="smurf_server_s3"
config_file=os.path.abspath("/usr/local/src/pysmurf/cfg_files/b33/experiment_b33_rfc1-2_C05-40_s4_lbOnlyBay0_fiber.cfg")
S = pysmurf.client.SmurfControl(epics_root=epics_prefix,cfg_file=config_file,setup=False,make_logfile=False,shelf_manager="shm-smrf-sp01")
# Out:
# [ 2024-08-08 22:04:59 ]  ERROR : band 0 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-08-08 22:04:59 ]  ERROR : band 1 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-08-08 22:04:59 ]  ERROR : band 2 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2024-08-08 22:04:59 ]  ERROR : band 3 is present in pysmurf cfg file, but its bay is not enabled!

# %% [markdown]
# AMC SMuRF

# %%
epics_prefix="smurf_server_s4"
config_file=os.path.abspath("/usr/local/src/pysmurf/cfg_files/b33/experiment_b33_rfc1-2_C05-40_s4_lbOnlyBay0_backplane.cfg")
Samc = pysmurf.client.SmurfControl(epics_root=epics_prefix,cfg_file=config_file,setup=False,make_logfile=False,shelf_manager="shm-smrf-sp01")

# %%
S.setup()
# Out:
# [ 2024-08-08 22:05:06 ]  System already configured once while this Rogue server has been up.
# [ 2024-08-08 22:05:06 ]  If you really want to configure again, run setup with force_configure=True.
# False

# %% [markdown]
# Is timing up?

# %%
S.get_timing_link_up()
# Out:
# 1

# %% [markdown]
# What versions of everything are we running?

# %%
pysmurf.__version__
# Out:
# '8.0.0-rc3+12.gc1067044'

# %%
# !git branch
# Out:
# * (HEAD detached from v8.0.0-rc3)
#   zcu208-devel

# %%
S._caget(f'{epics_prefix}:AMCc:RogueVersion', as_string=True)
# Out:
# 'v4.11.11'

# %%
S._caget(f'{epics_prefix}:AMCc:SmurfApplication:SmurfVersion', as_string=True)
# Out:
# '8.0.0-rc3'

# %%
S._caget(f'{epics_prefix}:AMCc:SmurfApplication:StartupArguments', as_string=True)
# Out:
# '-w smurf_server_s4 -e smurf_server_s4 -l 2 -a 10.0.1.104 -z /tmp/fw/rogue_MicrowaveMuxBpEthGen2_v1.1.1.zip --disable-bay1 -d /tmp/fw/smurf_cfg/defaults/defaults_c03_lb_none.yml --enable-em22xx'

# %%
S.get_fpga_git_hash_short()
# Out:
# 'e54bbcc'

# %% [markdown]
# Check timing configuration

# %%
print(S.get_timing_mode())
# Out:
# fiber

# %%
S.set_downsample_mode('external')
S.set_downsample_factor(20)

# %% [markdown]
# Chao reports unable to get flux ramping to work on band 3.

# %%
for band in S._bands:
    print(f'b{band} : {len(S.which_on(band))}')
# Out:
# b0 : 0
# b1 : 0
# b2 : 5
# b3 : 0

# %% [markdown]
# Let's kill the channels in band 2.

# %%
band=3
for chan in S.which_on(band):
    S.channel_off(band,chan)

# %% [markdown]
# Let's turn off the flux ramp and make sure the band 3 resonators are locked.

# %%
band=2
freqs, resps = S.find_freq(band=band, start_freq=-5, stop_freq=5, tone_power=12,grad_cut=0.01, amp_cut=0.1,make_plot=True,show_plot=True)
# Out:
# [ 2024-08-08 22:42:03 ]  Sweeping across frequencies 5245.0MHz to 5255.0MHz
# [ 2024-08-08 22:42:03 ]  Working on band 2
# [ 2024-08-08 22:42:06 ]  serial find freq complete ; etaScanInProgress = 0

# %%
for band in bands:
    # Tune
    S.setup_notches(band,new_master_assignment=True)
    
    # Refine tuning
    S.run_serial_gradient_descent(band)
    
    # Refine eta calibrations
    S.run_serial_eta_scan(band)
    S.plot_tune_summary(band,eta_scan=True,show_plot=True)
# Out:
# [ 2024-08-09 00:10:55 ]  No tone_power given. Using value in config file: 12
# [ 2024-08-09 00:10:55 ]  freq 5245.1200 - 1 of 5
# [ 2024-08-09 00:10:55 ]  freq 5247.6800 - 2 of 5
# [ 2024-08-09 00:10:55 ]  freq 5250.2800 - 3 of 5
# [ 2024-08-09 00:10:55 ]  freq 5252.7600 - 4 of 5
# [ 2024-08-09 00:10:55 ]  freq 5254.4800 - 5 of 5
# [ 2024-08-09 00:10:55 ]  Writing new channel assignment to /data/smurf_data/tune/1723162255_channel_assignment_b2.txt
# [ 2024-08-09 00:10:55 ]  Old master assignment file: /data/smurf_data/tune/1723156953_channel_assignment_b2.txt
# [ 2024-08-09 00:10:55 ]  New master assignment file: /data/smurf_data/tune/1723162255_channel_assignment_b2.txt
# [ 2024-08-09 00:11:01 ]  serial find freq complete ; etaScanInProgress = 0
# [ 2024-08-09 00:11:01 ]  Assigning channels
# [ 2024-08-09 00:11:01 ]  Writing new channel assignment to /data/smurf_data/tune/1723162262_channel_assignment_b2.txt
# [ 2024-08-09 00:11:01 ]  Old master assignment file: /data/smurf_data/tune/1723162255_channel_assignment_b2.txt
# [ 2024-08-09 00:11:01 ]  New master assignment file: /data/smurf_data/tune/1723162262_channel_assignment_b2.txt
# [ 2024-08-09 00:11:01 ]  Saving to : /data/smurf_data/tune/1723162262_tune.npy
# [ 2024-08-09 00:11:01 ]  Relocking...
# [ 2024-08-09 00:11:05 ]  Setting on 5 channels on band 2
# [ 2024-08-09 00:11:16 ]  Eta plot 1 of 5
# [ 2024-08-09 00:11:17 ]  Eta plot 2 of 5
# [ 2024-08-09 00:11:17 ]  Eta plot 3 of 5
# [ 2024-08-09 00:11:18 ]  Eta plot 4 of 5
# [ 2024-08-09 00:11:19 ]  Eta plot 5 of 5

# %%
bands=[2]
for band in bands:
    for chan in S.which_on(band):
        print(f'band={band} chan={chan} : {S.channel_to_freq(band,chan)}')
# Out:
# band=2 chan=0 : 5250.265995168686
# band=2 chan=64 : 5254.4600121974945
# band=2 chan=127 : 5245.207966089249
# band=2 chan=128 : 5252.82195482254
# band=2 chan=255 : 5247.764036178589

# %%
Samc.flux_ramp_off()

band=2
S.set_band_delay_us(band,8.5)

# Fast re-estimate of each resonator's frequency
S.run_serial_gradient_descent(band)

# Fast re-estimate of resonator circle calibration
S.run_serial_eta_scan(band)

# %% [markdown]
# Before moving on to tracking, let's make sure neither the ADC or DAC are saturated;

# %%
band=2
S.check_dac_saturation(band)
S.check_adc_saturation(band)
# Out:
# [ 2024-08-09 00:11:40 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 4096
# [ 2024-08-09 00:11:40 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 2
# [ 2024-08-09 00:11:41 ]  DAC2 max count: 1522
# [ 2024-08-09 00:11:41 ]  DAC2 min count: -1676
# [ 2024-08-09 00:11:41 ]  DAC2 not saturated
# [ 2024-08-09 00:11:41 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 4096
# [ 2024-08-09 00:11:41 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 2
# [ 2024-08-09 00:11:41 ]  ADC2 max count: 287
# [ 2024-08-09 00:11:41 ]  ADC2 min count: -289
# [ 2024-08-09 00:11:41 ]  ADC2 not saturated
# False

# %% [markdown]
# Not clipping either the RF DAC or ADC.

# %% [markdown]
# ## Tracking setup

# %% [markdown]
# Can we see modulation with feedback disabled?

# %%
band=2
S.set_feedback_enable(band,0)
S.tracking_setup(band, channel = S.which_on(band), reset_rate_khz=4, make_plot=True, save_plot=True, show_plot=True, 
                  lms_freq_hz=None, n_phi0=5, meas_flux_ramp_amp=True, fraction_full_scale=0.2,feedback_gain=2048,lms_gain=0,
                  return_data=False, feedback_start_frac=0.2, feedback_end_frac=0.98,nsamp = 2**18, new_epics_root='smurf_server_s4')
# Out:
# [ 2024-08-09 00:11:44 ]  Using LMS gain is now an advanced feature.
# [ 2024-08-09 00:11:44 ]  Unless you are an expert, you probably want feedback_gain.
# [ 2024-08-09 00:11:44 ]  See tracking_setup docstring.
# [ 2024-08-09 00:11:44 ]  Starting fraction full scale : 0.489
# [ 2024-08-09 00:11:45 ]  Percent full scale = 48.900%
# [ 2024-08-09 00:11:45 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:singleChannelReadout 0
# [ 2024-08-09 00:11:45 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:singleChannelReadoutOpt2 0
# [ 2024-08-09 00:11:45 ]  Writing to file : /data/smurf_data/20240808/1723154700/outputs/1723162305.dat
# [ 2024-08-09 00:11:45 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 524288
# [ 2024-08-09 00:11:45 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 2
# [ 2024-08-09 00:11:45 ]  Data acquisition in progress...
# [ 2024-08-09 00:11:45 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2024-08-09 00:11:46 ]  Done taking data
# [ 2024-08-09 00:11:47 ]  Number of channels on : 5
# [ 2024-08-09 00:11:47 ]  Number of channels on with flux ramp response : 5
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Percent full scale = 81.500%
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:11:47 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:11:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:singleChannelReadout 0
# [ 2024-08-09 00:11:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:singleChannelReadoutOpt2 0
# [ 2024-08-09 00:11:47 ]  Writing to file : /data/smurf_data/20240808/1723154700/outputs/1723162308.dat
# [ 2024-08-09 00:11:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 262144
# [ 2024-08-09 00:11:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 2
# [ 2024-08-09 00:11:47 ]  Data acquisition in progress...
# [ 2024-08-09 00:11:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2024-08-09 00:11:48 ]  Done taking data
# [ 2024-08-09 00:11:49 ]  Number of channels on : 5
# [ 2024-08-09 00:11:49 ]  Number of channels on with flux ramp response : 5

# %% [markdown]
# That looks ok.  Let's see if it can track on them with feedback enabled.  Only plot 10 channels or else it will take forever.

# %%
S.toggle_feedback(2)
# Out:
# [ 2024-08-09 00:11:59 ]  Before toggling feedback on band 2, feedbackEnable=0, lmsEnable1=1, lmsEnable2=1, and lmsEnable3=1.
# [ 2024-08-09 00:11:59 ]  Setting feedbackEnable=lmsEnable1=lmsEnable2=lmsEnable3=0 (in that order).
# [ 2024-08-09 00:11:59 ]  Set lmsEnable1=lmsEnable2=lmsEnable3=1 (in that order).

# %%
band=2
S.set_feedback_enable(band,1)
S.tracking_setup(band, channel = S.which_on(band), reset_rate_khz=4, make_plot=True, save_plot=True, show_plot=True, 
                  lms_freq_hz=None, n_phi0=5, meas_flux_ramp_amp=False, fraction_full_scale=0.195,feedback_gain=2048,lms_gain=0,
                  return_data=False, feedback_start_frac=0.2, feedback_end_frac=0.98,nsamp = 2**18, new_epics_root='smurf_server_s4')
# Out:
# [ 2024-08-09 00:12:00 ]  Using LMS gain is now an advanced feature.
# [ 2024-08-09 00:12:00 ]  Unless you are an expert, you probably want feedback_gain.
# [ 2024-08-09 00:12:00 ]  See tracking_setup docstring.
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Percent full scale = 19.500%
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  Temporarily using new epics root: smurf_server_s4
# [ 2024-08-09 00:12:01 ]  Returning back to original epics root : smurf_server_s3
# [ 2024-08-09 00:12:01 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:singleChannelReadout 0
# [ 2024-08-09 00:12:01 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:singleChannelReadoutOpt2 0
# [ 2024-08-09 00:12:01 ]  Writing to file : /data/smurf_data/20240808/1723154700/outputs/1723162321.dat
# [ 2024-08-09 00:12:01 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 262144
# [ 2024-08-09 00:12:01 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 2
# [ 2024-08-09 00:12:01 ]  Data acquisition in progress...
# [ 2024-08-09 00:12:01 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2024-08-09 00:12:02 ]  Done taking data
# [ 2024-08-09 00:12:02 ]  Number of channels on : 5
# [ 2024-08-09 00:12:02 ]  Number of channels on with flux ramp response : 5

# %% [markdown]
# That actually looks ok.

# %% [markdown]
# ## Take noise data

# %% [markdown]
# We're mostly tracking ~200 resonators.  Let's let it rip with the RFSoC, just for kicks.

# %%
S.take_noise_psd(60,show_plot=True)
# Out:
# [ 2024-08-09 00:12:16 ]  Starting to take data.
# [ 2024-08-09 00:12:16 ]  Input downsample factor is None. Using value already in pyrogue: 20
# [ 2024-08-09 00:12:16 ]  Flux ramp is AC-coupled.
# [ 2024-08-09 00:12:17 ]  caput smurf_server_s3:AMCc:SmurfProcessor:Unwrapper:reset 1
# [ 2024-08-09 00:12:17 ]  caput smurf_server_s3:AMCc:SmurfProcessor:Filter:reset 1
# [ 2024-08-09 00:12:17 ]  Writing to file : /data/smurf_data/20240808/1723154700/outputs/1723162338.dat
# [ 2024-08-09 00:12:17 ]  /data/smurf_data/20240808/1723154700/outputs/1723162338_mask.txt
# [ 2024-08-09 00:12:17 ]  Writing frequency mask.
# [ 2024-08-09 00:12:18 ]  caput smurf_server_s3:AMCc:SmurfProcessor:FileWriter:Open 1
# [ 2024-08-09 00:13:18 ]  caput smurf_server_s3:AMCc:SmurfProcessor:FileWriter:Close 1
# [ 2024-08-09 00:13:18 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:enableStreaming 0
# [ 2024-08-09 00:13:18 ]  Waiting 0.15 seconds after...
# [ 2024-08-09 00:13:18 ]  Done waiting.
# [ 2024-08-09 00:13:18 ]  Done taking data.
# [ 2024-08-09 00:13:18 ]  Reading /data/smurf_data/20240808/1723154700/outputs/1723162338.dat
# Processing data records from /data/smurf_data/20240808/1723154700/outputs/1723162338.dat
# [ 2024-08-09 00:13:18 ]  2048 elements loaded
# [ 2024-08-09 00:13:18 ]  4096 elements loaded
# [ 2024-08-09 00:13:18 ]  6144 elements loaded
# [ 2024-08-09 00:13:18 ]  8192 elements loaded
# [ 2024-08-09 00:13:18 ]  10240 elements loaded
# Processed 12008 data records from /data/smurf_data/20240808/1723154700/outputs/1723162338.dat
# Processed a total of 12008 data records
# [ 2024-08-09 00:13:18 ]  Plotting [2 2 2 2 2], [  0  64 127 128 255]
# [ 2024-08-09 00:13:18 ]  1. b2ch000: white-noise level = 50.77 pA/rtHz, n = 0.84, f_knee = 0.04 Hz
# [ 2024-08-09 00:13:18 ]  53.287130783367104
# [ 2024-08-09 00:13:20 ]  2. b2ch064: white-noise level = 44.95 pA/rtHz, n = 0.71, f_knee = 0.02 Hz
# [ 2024-08-09 00:13:20 ]  46.95562109978537
# [ 2024-08-09 00:13:21 ]  3. b2ch127: white-noise level = 44.10 pA/rtHz, n = 0.53, f_knee = 0.01 Hz
# [ 2024-08-09 00:13:21 ]  46.4187587534484
# [ 2024-08-09 00:13:22 ]  4. b2ch128: white-noise level = 43.41 pA/rtHz, n = 0.77, f_knee = 0.01 Hz
# [ 2024-08-09 00:13:22 ]  43.476548682840004
# [ 2024-08-09 00:13:23 ]  5. b2ch255: white-noise level = 44.28 pA/rtHz, n = 0.67, f_knee = 0.01 Hz
# [ 2024-08-09 00:13:23 ]  45.119325231593415
# '/data/smurf_data/20240808/1723154700/outputs/1723162338.dat'

# %% [markdown]
# Here's a hack for looking at individual timestream plots; first one on SMB that's dark;

# %%
#Import library
from IPython.display import Image
# Load image from local storage
plt.ion()

Image(filename = "/data/smurf_data/20240808/1723154700/plots/1723162338_noise_timestream_b2_ch255.png", width = 600, height = 300)
