# %% [markdown]
# ## Load, check, and record configuration

# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
import yaml
import time
import pickle as pkl
import os
import numpy as np
from matplotlib import cm
from scipy.signal import welch,periodogram
import pandas as pd
import glob
from scipy.optimize import curve_fit
from scipy import signal

import pysmurf.client
import matplotlib.pylab as plt
import numpy as np
import sys
import os
epics_prefix="smurf_server_s4"
config_file=os.path.abspath("/usr/local/src/pysmurf/cfg_files/spt3gplus/experiment_spt3gplus_lbOnlyBay0_c02-01.cfg")
S = pysmurf.client.SmurfControl(epics_root=epics_prefix,cfg_file=config_file,setup=False,make_logfile=False,shelf_manager="shm-smrf-sp01")

# %% [markdown]
# What versions of everything are we running?

# %%
pysmurf.__version__
# Out:
# '8.1.0'

# %%
# !git branch
# Out:
# * spt3g+proto

# %%
S._caget(f'{epics_prefix}:AMCc:RogueVersion', as_string=True)
# Out:
# 'v4.11.11'

# %%
S._caget(f'{epics_prefix}:AMCc:SmurfApplication:SmurfVersion', as_string=True)
# Out:
# '8.1.0'

# %%
S._caget(f'{epics_prefix}:AMCc:SmurfApplication:StartupArguments', as_string=True)
# Out:
# '-w smurf_server_s4 -e smurf_server_s4 -l 2 -a 10.0.1.104 -z /tmp/fw/rogue_MicrowaveMuxBpEthGen2_v1.3.0.zip --disable-bay1 -d /tmp/fw/smurf_cfg/defaults/defaults_c02_lb_none.yml --enable-em22xx'

# %%
S.get_fpga_git_hash_short()
# Out:
# '1feb01f'

# %% [markdown]
# `shawnhammer` ran `setup()` already.  Make sure JESD is locked:

# %%
S.check_jesd(0)
# Out:
# [ 2025-09-10 16:49:14 ]  JESD Tx Okay
# [ 2025-09-10 16:49:14 ]  JESD Rx Okay
# [ 2025-09-10 16:49:15 ]  JESD health check finished after 1 seconds. The final status was Locked.
# (True, True, 'Locked')

# %% [markdown]
# Check communication with cryocard and its fw version

# %% [markdown]
# What hardware are we using?  use_shell=True is slower but doesn't require the atca_monitor docker.

# %%
S.get_carrier_sn(use_shell=True)
# Out:
# 'C03-A03-20'

# %%
S.get_rtm_sn(use_shell=True)
# Out:
# 'C01-C01-A01-09'

# %%
S.get_amc_sn(0,use_shell=True)
# Out:
# 'C02-04'

# %% [markdown]
# # Single channel

# %% [markdown]
# SQUAT data taking has been using `take_debug_data` like this (from https://github.com/DMQIS/SQUAT_DAQ/blob/main/Measurements/SMURF/daily_logs/2025_0818_alex_and_hannah_starting.ipynb);

# %%
def welch_IQ(iq, fs,  plot=True, welch_nperseg=2**18, title='', show_plot=True):
    i = iq.real
    q = iq.imag
    ffi, pxxi = welch(i,fs=fs, nperseg=welch_nperseg)
    ffq, pxxq = welch(q,fs=fs, nperseg=welch_nperseg)

    # scale to dBc/Hz by the voltage magnitude
    magfac = np.mean(q)**2 + np.mean(i)**2
    pxxi_dbc = 10. * np.log10(pxxi / magfac)
    pxxq_dbc = 10. * np.log10(pxxq / magfac)


    if plot:
        plt.gca().semilogx(ffi,pxxi_dbc,linestyle='-',label=f'i {title}')
        plt.gca().semilogx(ffq,pxxq_dbc, linestyle='--',label=f'q {title}')
        plt.ylabel('dBc/Hz')
        plt.xlabel('Frequency (Hz)')
        plt.title(title)
        plt.legend(loc='lower left')
        if show_plot: plt.show()
    return

def takeDebugData(S, band, channel, nsamp, plot=True, welch_nperseg=2**18, show_plot=True, channel_mode=2):
    timestamp = S.get_timestamp() 
    filename = f'{timestamp}_multi_channel_b{band}'
    if channel is not None:
        filename = f'{timestamp}_single_channel_b{band}ch{channel:03}'
    i,q,sync = S.take_debug_data(band=band,channel=channel,rf_iq=True,nsamp=nsamp,filename=filename, single_channel_readout=channel_mode) 
    i = i / (1.2)
    q = q / (-1.2)
    iq = i + 1j * q
    if plot: 
        fs = S.get_channel_frequency_mhz(band) * 1.0E6
        if channel_mode==1:
            fs/=2.
            fs/=(S.get_decimation(band)+1.)
        welch_IQ(iq, fs, welch_nperseg, title=filename, show_plot=show_plot)
        ### save plots 
        fig = plt.gcf()
        #plt.savefig(f'/data/smurf_data/mkid_1tone_streaming_metadata/_Figs/{filename}_psd', fmt='tiff')
        plt.show()
    return iq, sync, filename

# %% [markdown]
# Let's work first with a tone in the center of band 0.

# %%
band,channel=S.set_fixed_tone(S.get_band_center_mhz(0),12)

# %% [markdown]
# Try taking data the usual way

# %%
# %%time
iq,_,filename=takeDebugData(S,band=band,channel=channel,nsamp=2**25,plot=True,channel_mode=2)
# Out:
# [ 2025-09-10 18:10:25 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:readoutChannelSelect 0
# [ 2025-09-10 18:10:25 ]  Writing to file : /data/smurf_data/20250910/1757522936/outputs/1757527826_single_channel_b0ch000.dat
# [ 2025-09-10 18:10:25 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 33554432
# [ 2025-09-10 18:10:25 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2025-09-10 18:10:25 ]  Data acquisition in progress...
# [ 2025-09-10 18:10:25 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2025-09-10 18:10:41 ]  Done taking data
# CPU times: user 11.8 s, sys: 3.62 s, total: 15.4 s
# Wall time: 31.7 s

# %% [markdown]
# From above, it took <16 sec to take the data (the other ~15sec was for plotting and data handling, probably).  This is roughly consistent with 2**25 samples taken at 2.4 MHz ~ 14 sec acquisition.

# %% [markdown]
# Ok, now let's try mode 1.  This

# %% [markdown]
# In mode 1, signle channel data should be returned at 1.2 MHz, and you can optionally filter and downsample the data.  For reasons lost to time by default the downsampling is 2 (reg is set to 1, which corresponds to a decimation by (1+1) = 2);

# %% [markdown]
# To take data without any decimation, set to zero (for a sample decimation of 0+1=1;

# %%
S.set_decimation(band,0)
print(f'b0 decimation : {S.get_decimation(band)}')
# Out:
# b0 decimation : 0

# %%
# %%time
iq1,_,filename=takeDebugData(S,band=band,channel=channel,nsamp=2**25,plot=True,channel_mode=1)
# Out:
# [ 2025-09-10 18:10:57 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:readoutChannelSelect 0
# [ 2025-09-10 18:10:57 ]  Writing to file : /data/smurf_data/20250910/1757522936/outputs/1757527857_single_channel_b0ch000.dat
# [ 2025-09-10 18:10:57 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 33554432
# [ 2025-09-10 18:10:57 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2025-09-10 18:10:57 ]  Data acquisition in progress...
# [ 2025-09-10 18:10:57 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2025-09-10 18:11:27 ]  Done taking data
# CPU times: user 11.6 s, sys: 3.77 s, total: 15.3 s
# Wall time: 45.7 s

# %% [markdown]
# Here, acquisition took ~30sec as expected (2^25/(1.2e6) ~ 28 sec) and the noise agrees with the data taken in mode 0;

# %%
from scipy import ndimage

#ffq0, pxxq0 = welch(iq.imag,fs=2.4e6, nperseg=2**18)
#ffq1, pxxq1 = welch(iq1.imag,fs=1.2e6, nperseg=2**18)
plt.semilogx(ffq0,ndimage.median_filter(10*np.log10(pxxq0),size=1))
plt.semilogx(ffq1,ndimage.median_filter(10*np.log10(pxxq1),size=1))

# %% [markdown]
# If we want to take multichannel data, we should first configure the filter + downsample.  Here's how to set the filter for 10kHz;

# %%
S.set_debug_data_filter_cutoff(band, fcut_hz=10e3)
# Out:
# [ 2025-09-10 18:20:28 ]  Asked for a filter cut-off of 10000.000 Hz but got a cut-off of 9997.793 Hz due to rounding

# %% [markdown]
# Is filter being applied?

# %%
# %%time
iq1filt,_,filename=takeDebugData(S,band=band,channel=channel,nsamp=2**25,plot=True,channel_mode=1)
# Out:
# [ 2025-09-10 18:20:32 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:readoutChannelSelect 0
# [ 2025-09-10 18:20:32 ]  Writing to file : /data/smurf_data/20250910/1757522936/outputs/1757528432_single_channel_b0ch000.dat
# [ 2025-09-10 18:20:32 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 33554432
# [ 2025-09-10 18:20:32 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2025-09-10 18:20:32 ]  Data acquisition in progress...
# [ 2025-09-10 18:20:32 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2025-09-10 18:21:02 ]  Done taking data
# CPU times: user 11.5 s, sys: 3.81 s, total: 15.3 s
# Wall time: 45.6 s

# %%
from scipy import ndimage

ffq1filt, pxxq1filt = welch(iq1filt.imag,fs=1.2e6, nperseg=2**18)
plt.semilogx(ffq0,ndimage.median_filter(10*np.log10(pxxq0),size=3),alpha=0.75)
plt.semilogx(ffq1,ndimage.median_filter(10*np.log10(pxxq1),size=3),alpha=0.75)
plt.semilogx(ffq1filt,ndimage.median_filter(10*np.log10(pxxq1filt),size=3),alpha=0.75)

# %% [markdown]
# Looks plausible.  Ok, so now should be able to decimate without incurring a noise penalty.  Let's try decimating to 30 kHz, or a factor of 40.  Must remember to adjust nsamp or your acq will take forever!

# %%
S.set_decimation(band,39) # 39 is a decimation of 40, since the decimation is dec+1

# %%
# %%time
iq1filtdec,_,filename=takeDebugData(S,band=band,channel=channel,nsamp=int(2**25/(S.get_decimation(band)+1)),plot=True,channel_mode=1)
# Out:
# [ 2025-09-10 18:34:20 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:readoutChannelSelect 0
# [ 2025-09-10 18:34:20 ]  Writing to file : /data/smurf_data/20250910/1757522936/outputs/1757529260_single_channel_b0ch000.dat
# [ 2025-09-10 18:34:20 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 838860
# [ 2025-09-10 18:34:20 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2025-09-10 18:34:20 ]  Data acquisition in progress...
# [ 2025-09-10 18:34:20 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2025-09-10 18:34:49 ]  Done taking data
# CPU times: user 1.37 s, sys: 94.9 ms, total: 1.46 s
# Wall time: 30.8 s

# %%
from scipy import ndimage

ffq1filtdec, pxxq1filtdec = welch(iq1filtdec.imag,fs=1.2e6/(S.get_decimation(band)+1), nperseg=2**18)
plt.semilogx(ffq0,ndimage.median_filter(10*np.log10(pxxq0),size=3),alpha=0.75)
plt.semilogx(ffq1,ndimage.median_filter(10*np.log10(pxxq1),size=3),alpha=0.75)
plt.semilogx(ffq1filt,ndimage.median_filter(10*np.log10(pxxq1filt),size=3),alpha=0.75)
plt.semilogx(ffq1filtdec,ndimage.median_filter(10*np.log10(pxxq1filtdec),size=3),alpha=0.75)

# %% [markdown]
# Ok, should be ready for multitone now.

# %% [markdown]
# # Multitone

# %% [markdown]
# For multitone, just don't pass a channel.  Remember your samples will get split across the 416 fw channels and increase accordingly.  Also be aware these files can get *big*

# %%
# %%time
#iq1filtdecmultitone,_,filename=takeDebugData(S,band=band,channel=None,nsamp=int(S.get_number_processed_channels(band)*2**25/(S.get_decimation(band)+1)),plot=False)
iq1filtdecmultitone,_,filename=takeDebugData(S,band=band,channel=None,nsamp=2**25,plot=False)
# Out:
# [ 2025-09-10 19:03:16 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:singleChannelReadout 0
# [ 2025-09-10 19:03:16 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:singleChannelReadoutOpt2 0
# [ 2025-09-10 19:03:16 ]  Writing to file : /data/smurf_data/20250910/1757522936/outputs/1757530997_multi_channel_b0.dat
# [ 2025-09-10 19:03:16 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 33554432
# [ 2025-09-10 19:03:16 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2025-09-10 19:03:16 ]  Data acquisition in progress...
# [ 2025-09-10 19:03:16 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2025-09-10 19:03:22 ]  Done taking data
# CPU times: user 6.69 s, sys: 2 s, total: 8.69 s
# Wall time: 14 s

# %%
ffq1filtdecmultitone, pxxq1filtdecmultitone = welch(iq1filtdecmultitone.imag[0::416],fs=1.2e6/(S.get_decimation(band)+1), nperseg=2**18)
plt.semilogx(ffq0,ndimage.median_filter(10*np.log10(pxxq0),size=3),alpha=0.75)
plt.semilogx(ffq1,ndimage.median_filter(10*np.log10(pxxq1),size=3),alpha=0.75)
plt.semilogx(ffq1filt,ndimage.median_filter(10*np.log10(pxxq1filt),size=3),alpha=0.75)
plt.semilogx(ffq1filtdecmultitone,ndimage.median_filter(10*np.log10(pxxq1filtdecmultitone),size=3),alpha=0.75)

# %% [markdown]
# Good.  Now let's do a true multitone measurement.

# %%
S.band_off(band)
chans=[]
for foff in [-225,-135,-17,0,94,196]:
    (_,chan)=S.set_fixed_tone(S.get_band_center_mhz(band)+foff,12)

# %% [markdown]
# Which channels are on?

# %%
S.which_on(band)
# Out:
# array([  0,  69, 159, 228, 394, 483])

# %% [markdown]
# Take multitone data...

# %%
# %%time
#iq1filtdecmultitone,_,filename=takeDebugData(S,band=band,channel=None,nsamp=int(S.get_number_processed_channels(band)*2**25/(S.get_decimation(band)+1)),plot=False)
iq1filtdecmultitone2,_,filename=takeDebugData(S,band=band,channel=None,nsamp=2**24,plot=False)
# Out:
# [ 2025-09-10 19:16:02 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:singleChannelReadout 0
# [ 2025-09-10 19:16:02 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:singleChannelReadoutOpt2 0
# [ 2025-09-10 19:16:02 ]  Writing to file : /data/smurf_data/20250910/1757522936/outputs/1757531762_multi_channel_b0.dat
# [ 2025-09-10 19:16:02 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 16777216
# [ 2025-09-10 19:16:02 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# [ 2025-09-10 19:16:02 ]  Data acquisition in progress...
# [ 2025-09-10 19:16:02 ]  caput smurf_server_s4:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:TriggerDaq 1
# [ 2025-09-10 19:16:05 ]  Done taking data
# CPU times: user 3.41 s, sys: 1.03 s, total: 4.44 s
# Wall time: 7.8 s

# %% [markdown]
# Hm, the array indices don't seem to line up with what I expect.  Compare;

# %%
S.which_on(band)
# Out:
# array([  0,  69, 159, 228, 394, 483])

# %%
np.nonzero(iq1filtdecmultitone2[:416])
# Out:
# (array([  0,  56, 129, 185, 320, 392]),)

# %% [markdown]
# We may have found a SMuRF bug!

# %%
y_plotting_offset=0.005
for idx,chan in enumerate(np.nonzero(iq1filtdecmultitone2[:416])[0]):
    data=iq1filtdecmultitone2[chan::S.get_number_processed_channels(band)]
    plt.plot(data.imag-np.mean(data.imag)+y_plotting_offset*idx,label=f'chan={chan}')
#plt.plot(iq1filtdecmultitone2[56::416])
#plt.plot(iq1filtdecmultitone2[129::416])
plt.legend()
