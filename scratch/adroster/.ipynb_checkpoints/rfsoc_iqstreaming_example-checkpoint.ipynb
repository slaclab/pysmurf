# %%
# %matplotlib inline

# %%
import matplotlib
import pysmurf.client
import matplotlib.pylab as plt
import numpy as np
import sys
import os
epics_prefix="smurf_server_s3"
config_file=os.path.abspath("/usr/local/src/pysmurf/cfg_files/slab/experiment_slab_rfsoc_extref.cfg")
S = pysmurf.client.SmurfControl(epics_root=epics_prefix,cfg_file=config_file,setup=False,make_logfile=False,shelf_manager="shm-smrf-sp01")
# Out:
# [ 2026-03-24 00:12:37 ]  ERROR : band 0 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2026-03-24 00:12:37 ]  ERROR : band 1 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2026-03-24 00:12:37 ]  ERROR : band 2 is present in pysmurf cfg file, but its bay is not enabled!
# [ 2026-03-24 00:12:37 ]  ERROR : band 3 is present in pysmurf cfg file, but its bay is not enabled!

# %%
plt.ion()

# %% [markdown]
# # Setup

# %% [markdown]
# Only once per power on ; configure hardware

# %%
S.setup()
# Out:
# [ 2026-03-24 00:12:47 ]  System already configured, but will configure again since force_configure=True.
# [ 2026-03-24 00:12:47 ]  Setting up...
# [ 2026-03-24 00:12:47 ]  caput smurf_server_s3:AMCc:ReadAll 1
# [ 2026-03-24 00:12:52 ]  Waiting 20.00 seconds after...
# [ 2026-03-24 00:13:12 ]  Done waiting.
# [ 2026-03-24 00:13:12 ]  caget smurf_server_s3:AMCc:SmurfApplication:SmurfVersion
# [ 2026-03-24 00:13:12 ]  9.0.0+24.g2b076d38.dirty
# [ 2026-03-24 00:13:12 ]  caput smurf_server_s3:AMCc:setDefaults 1
# [ 2026-03-24 00:13:30 ]  caget smurf_server_s3:AMCc:SmurfApplication:ConfiguringInProgress
# [ 2026-03-24 00:13:30 ]  False
# [ 2026-03-24 00:13:30 ]  caget smurf_server_s3:AMCc:SmurfApplication:SystemConfigured
# [ 2026-03-24 00:13:30 ]  True
# [ 2026-03-24 00:13:30 ]  System configuration finished after 17 seconds. The final state was True.
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:iqSwapIn 0
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:iqSwapOut 1
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:refPhaseDelay 6
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:refPhaseDelayFine 16
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:lmsDelay 6
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:lmsGain 1
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:trigRstDly 15
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:feedbackEnable 1
# [ 2026-03-24 00:13:30 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:feedbackGain 2048
# [ 2026-03-24 00:13:31 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:feedbackLimit 6144.0
# [ 2026-03-24 00:13:31 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:feedbackPolarity 1
# [ 2026-03-24 00:13:31 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:dspEnable 1
# [ 2026-03-24 00:13:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:gradientDescentGain 0.0001
# [ 2026-03-24 00:13:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:gradientDescentAverages 1
# [ 2026-03-24 00:13:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:gradientDescentConvergeHz 500.0
# [ 2026-03-24 00:13:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:gradientDescentStepHz 1000.0
# [ 2026-03-24 00:13:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:gradientDescentMomentum 1
# [ 2026-03-24 00:13:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:gradientDescentBeta 0.0
# [ 2026-03-24 00:13:32 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:etaScanAverages 1
# [ 2026-03-24 00:13:33 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[0]:CryoChannels:etaScanDelF 5000
# [ 2026-03-24 00:13:33 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:iqSwapIn 0
# [ 2026-03-24 00:13:33 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:iqSwapOut 1
# [ 2026-03-24 00:13:33 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:refPhaseDelay 6
# [ 2026-03-24 00:13:33 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:refPhaseDelayFine 19
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:lmsDelay 6
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:lmsGain 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:trigRstDly 15
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:feedbackEnable 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:feedbackGain 2048
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:feedbackLimit 6144.0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:feedbackPolarity 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:dspEnable 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:gradientDescentGain 0.0001
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:gradientDescentAverages 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:gradientDescentConvergeHz 500.0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:gradientDescentStepHz 1000.0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:gradientDescentMomentum 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:gradientDescentBeta 0.0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:etaScanAverages 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[1]:CryoChannels:etaScanDelF 5000
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:iqSwapIn 0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:iqSwapOut 0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:refPhaseDelay 6
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:refPhaseDelayFine 19
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:lmsDelay 6
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:lmsGain 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:trigRstDly 15
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:feedbackEnable 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:feedbackGain 2048
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:feedbackLimit 6144.0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:feedbackPolarity 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:dspEnable 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:gradientDescentGain 0.0001
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:gradientDescentAverages 1
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:gradientDescentConvergeHz 500.0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:gradientDescentStepHz 1000.0
# [ 2026-03-24 00:13:34 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:gradientDescentMomentum 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:gradientDescentBeta 0.0
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:etaScanAverages 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[2]:CryoChannels:etaScanDelF 5000
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:iqSwapIn 0
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:iqSwapOut 0
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:refPhaseDelay 6
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:refPhaseDelayFine 16
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:lmsDelay 6
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:lmsGain 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:trigRstDly 15
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:feedbackEnable 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:feedbackGain 2048
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:feedbackLimit 6144.0
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:feedbackPolarity 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:dspEnable 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:gradientDescentGain 0.0001
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:gradientDescentAverages 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:gradientDescentConvergeHz 500.0
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:gradientDescentStepHz 1000.0
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:gradientDescentMomentum 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:gradientDescentBeta 0.0
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:etaScanAverages 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:SysgenCryo:Base[3]:CryoChannels:etaScanDelF 5000
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AmcCarrierCore:AmcCarrierTiming:EvrV2CoreTriggers:EvrV2TriggerReg[0]:Width 10
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AmcCarrierCore:AmcCarrierTiming:EvrV2CoreTriggers:EvrV2TriggerReg[0]:EnableTrig 1
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AmcCarrierCore:AmcCarrierTiming:EvrV2CoreTriggers:EvrV2ChannelReg[0]:EnableReg True
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AmcCarrierCore:AmcCarrierTiming:EvrV2CoreTriggers:EvrV2ChannelReg[0]:DestSel 131072
# [ 2026-03-24 00:13:35 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:EnableRampTrigger 1
# [ 2026-03-24 00:13:35 ]  Turning off tones
# [ 2026-03-24 00:13:45 ]  Turning off flux ramp
# [ 2026-03-24 00:13:45 ]  Turning off all TES biases
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:RtmSpiSr:CfgRegEnaBit 0
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:RtmSpiSr:CfgRegEnaBit 0
# [ 2026-03-24 00:13:47 ]  Percent full scale = 48.900%
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:LowCycle 5
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:HighCycle 5
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:KRelay 3
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:RampMaxCnt 76799.0
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:PulseWidth 64
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:DebounceWidth 255
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:RtmSpiSr:RampSlope 0
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:RtmSpiSr:ModeControl 0
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:RtmSpiSr:FastSlowStepSize 328162
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:RtmSpiSr:FastSlowRstValue 1097365248.0
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:RtmCryoDet:EnableRampTrigger 1
# [ 2026-03-24 00:13:47 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:enableStreaming 1
# [ 2026-03-24 00:13:47 ]  Configuring the system to take timing from ext_ref
# [ 2026-03-24 00:13:48 ]  System already configured for ext_ref timing, doing nothing.
# [ 2026-03-24 00:13:48 ]  Done with setup.
# True

# %% [markdown]
# We're going to take I,Q data.  This is not standard data-taking, so have to set some flags to enable it.  Currently, this data mode is only supported for one bay at a time.  So we have to select I/Q data mode, and tell it which bay to give us data from.  The "bay" concept is only meaningful in the original SMuRF ATCA hardware context; for the RFSoC bay 0 just means bands 0,1,2,3 and bay 1 means bands 4,5,6,7.

# %%
S._caput(f'{S.app_core}baySelStream', 0, write_log=True) # going to be streaming I/Q for bay 0 only.
S._caput(f'{S.app_core}modeStream', 1,write_log=True) # =1 means to stream I/Q data, which is a nonstandard mode.
# Out:
# [ 2026-03-24 00:13:48 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:baySelStream 0
# [ 2026-03-24 00:13:48 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:modeStream 1

# %% [markdown]
# Which band are we working in?

# %%
band=0

# %% [markdown]
# This register truncates IQ data in streaming mode.  Set to 7 to eliminate truncation.

# %%
S.set_lms_gain(band,7)

# %% [markdown]
# ## Taking streaming data

# %% [markdown]
# The RFSoC thinks it's a SMuRF system.  Disabuse it of this notion.

# %%
S.set_band_center_mhz(band,750)

# %% [markdown]
# Set some tones to stream IQ data for.

# %%
S.set_fixed_tone(511.101,12)
S.set_fixed_tone(575.292,12)
S.set_fixed_tone(636.383,12)
S.set_fixed_tone(694.474,12)
S.set_fixed_tone(728.565,12)
S.set_fixed_tone(755.656,12)
S.set_fixed_tone(812.747,12)
S.set_fixed_tone(879.838,12)
S.set_fixed_tone(931.929,12)
S.set_fixed_tone(989.010,12)
# Out:
# (0, 454)

# %% [markdown]
# What's on?

# %%
S.which_on(band)
# Out:
# array([ 50,  88, 108, 151, 237, 239, 267, 313, 320, 454])

# %% [markdown]
# What does the raw ADC data look like?

# %%
adc=S.read_adc_data(band,make_plot=True,show_plot=True)
# Out:
# [ 2026-03-24 00:13:54 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:DaqMuxV2[0]:DataBufferSize 524288
# [ 2026-03-24 00:13:54 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:DebugSelect[0] 0
# /usr/local/src/pysmurf/python/pysmurf/client/util/smurf_util.py:1770: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig(plot_fn)
# [ 2026-03-24 00:13:56 ]  ADC plot saved to /data/smurf_data/20260324/1774311158/plots/1774311234_adc0.png
# [ 2026-03-24 00:13:56 ]  Saving raw adc data to /data/smurf_data/20260324/1774311158/outputs/1774311234_adc0
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Good, there's 10 tones.

# %% [markdown]
# Let's stream some data.  Start off with streaming off, and try for 37 kHz (probably the fastest we can go until Jenny finished on-going speed up project).  Currently, we're tricking the SMuRF firmware into sampling at 37 kHz by setting the flux ramp to that, even though there is no flux ramp.  That just gets sample triggering running.

# %%
S.stream_data_off()
S.flux_ramp_setup(37.5,0)
# Out:
# [ 2026-03-24 00:46:54 ]  caput smurf_server_s3:AMCc:SmurfProcessor:FileWriter:Close 1
# [ 2026-03-24 00:46:54 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:enableStreaming 0
# [ 2026-03-24 00:46:54 ]  Waiting 0.15 seconds after...
# [ 2026-03-24 00:46:54 ]  Done waiting.
# [ 2026-03-24 00:46:54 ]  Percent full scale = 0.000%

# %% [markdown]
# Want to stream with no filter, and with no downsampling, because we are insane

# %%
S.set_filter_disable(False)
S.set_downsample_factor(1)

print(f'S.get_sample_frequency()={S.get_sample_frequency()}')
print(f'S.get_downsample_factor()={S.get_downsample_factor()}')
print(f'S.get_filter_disable()={S.get_filter_disable()}')
# Out:
# S.get_sample_frequency()=37500.0
# S.get_downsample_factor()=1
# S.get_filter_disable()=0

# %% [markdown]
# Let's set the filter

# %%
import scipy.signal as signal
# I think this configures for a 12 kHz roll-off.
b, a = signal.butter(4, 12.0 / 37.5)
S.set_filter_a(a)
S.set_filter_b(b)

# %% [markdown]
# Lost frames is a concern at high rate, so we'll check frame and frame loss counts before and after taking data.

# %%
cnt0=S.get_frame_count()
losscnt0=S.get_frame_loss_cnt()

# Here IQ_mode tells the data-taking and read-back that we're taking data in the nonstandard I/Q mode.
data_file=S.take_stream_data(10,IQ_mode=True)

cnt1=S.get_frame_count()
losscnt1=S.get_frame_loss_cnt()
# Out:
# [ 2026-03-24 00:49:24 ]  Starting to take data.
# [ 2026-03-24 00:49:24 ]  Input downsample factor is None. Using value already in pyrogue: 1
# [ 2026-03-24 00:49:24 ]  CryoCard.do_read failed, retry 1 / 5.
# [ 2026-03-24 00:49:24 ]  CryoCard.do_read failed, retry 2 / 5.
# [ 2026-03-24 00:49:24 ]  CryoCard.do_read failed, retry 3 / 5.
# [ 2026-03-24 00:49:24 ]  CryoCard.do_read failed, retry 4 / 5.
# [ 2026-03-24 00:49:24 ]  CryoCard.do_read failed, retry 5 / 5.
# [ 2026-03-24 00:49:24 ]  flux_ramp_ac_dc_relay status: Failed to read from cryo card.
# [ 2026-03-24 00:49:24 ]  flux_ramp_ac_dc_relay_status = None - NOT A VALID STATE.
# [ 2026-03-24 00:49:27 ]  caput smurf_server_s3:AMCc:SmurfProcessor:Unwrapper:reset 1
# [ 2026-03-24 00:49:27 ]  caput smurf_server_s3:AMCc:SmurfProcessor:Filter:reset 1
# [ 2026-03-24 00:49:27 ]  Writing to file : /data/smurf_data/20260324/1774311158/outputs/1774313367.dat
# [ 2026-03-24 00:49:27 ]  /data/smurf_data/20260324/1774311158/outputs/1774313367_mask.txt
# [ 2026-03-24 00:49:27 ]  Writing frequency mask.
# [ 2026-03-24 00:49:27 ]  caput smurf_server_s3:AMCc:SmurfProcessor:FileWriter:Open 1
# [ 2026-03-24 00:49:37 ]  caput smurf_server_s3:AMCc:SmurfProcessor:FileWriter:Close 1
# [ 2026-03-24 00:49:37 ]  caput smurf_server_s3:AMCc:FpgaTopLevel:AppTop:AppCore:enableStreaming 0
# [ 2026-03-24 00:49:37 ]  Waiting 0.15 seconds after...
# [ 2026-03-24 00:49:38 ]  Done waiting.
# [ 2026-03-24 00:49:38 ]  Done taking data.

# %% [markdown]
# Did we get the number of frames we were expecting, and where there any lost frames?

# %%
print(f'Number of frames = {cnt1-cnt0}')
print(f'Number of frames lost = {losscnt1-losscnt0}')
# Out:
# Number of frames = 332882
# Number of frames lost = 0

# %%
print(f'Expected {10./(1./(1.e3*S.get_flux_ramp_freq()))} frames')
# Out:
# Expected 375000.0 frames

# %% [markdown]
# Close, but may want to pull it back a little.  Didn't register any dropped frames, but at these higher rates there be counters we don't usually check which we should worry about.

# %%
t,d,m,h=S.read_stream_data(data_file,return_header=True)
# Out:
# [ 2026-03-24 00:49:45 ]  Reading /data/smurf_data/20260324/1774311158/outputs/1774313367.dat
# Processing data records from /data/smurf_data/20260324/1774311158/outputs/1774313367.dat
# [ 2026-03-24 00:49:46 ]  2048 elements loaded
# (0, 16) (2048, 16)
# [ 2026-03-24 00:49:47 ]  4096 elements loaded
# (2048, 16) (2048, 16)
# [ 2026-03-24 00:49:48 ]  6144 elements loaded
# (4096, 16) (2048, 16)
# [ 2026-03-24 00:49:48 ]  8192 elements loaded
# (6144, 16) (2048, 16)
# [ 2026-03-24 00:49:49 ]  10240 elements loaded
# (8192, 16) (2048, 16)
# [ 2026-03-24 00:49:50 ]  12288 elements loaded
# (10240, 16) (2048, 16)
# [ 2026-03-24 00:49:51 ]  14336 elements loaded
# (12288, 16) (2048, 16)
# [ 2026-03-24 00:49:52 ]  16384 elements loaded
# (14336, 16) (2048, 16)
# [ 2026-03-24 00:49:52 ]  18432 elements loaded
# (16384, 16) (2048, 16)
# [ 2026-03-24 00:49:53 ]  20480 elements loaded
# (18432, 16) (2048, 16)
# [ 2026-03-24 00:49:54 ]  22528 elements loaded
# (20480, 16) (2048, 16)
# [ 2026-03-24 00:49:55 ]  24576 elements loaded
# (22528, 16) (2048, 16)
# [ 2026-03-24 00:49:55 ]  26624 elements loaded
# (24576, 16) (2048, 16)
# [ 2026-03-24 00:49:56 ]  28672 elements loaded
# (26624, 16) (2048, 16)
# [ 2026-03-24 00:49:57 ]  30720 elements loaded
# (28672, 16) (2048, 16)
# [ 2026-03-24 00:49:58 ]  32768 elements loaded
# (30720, 16) (2048, 16)
# [ 2026-03-24 00:49:59 ]  34816 elements loaded
# (32768, 16) (2048, 16)
# [ 2026-03-24 00:49:59 ]  36864 elements loaded
# (34816, 16) (2048, 16)
# [ 2026-03-24 00:50:00 ]  38912 elements loaded
# (36864, 16) (2048, 16)
# [ 2026-03-24 00:50:01 ]  40960 elements loaded
# (38912, 16) (2048, 16)
# [ 2026-03-24 00:50:02 ]  43008 elements loaded
# (40960, 16) (2048, 16)
# [ 2026-03-24 00:50:03 ]  45056 elements loaded
# (43008, 16) (2048, 16)
# [ 2026-03-24 00:50:03 ]  47104 elements loaded
# (45056, 16) (2048, 16)
# [ 2026-03-24 00:50:04 ]  49152 elements loaded
# (47104, 16) (2048, 16)
# [ 2026-03-24 00:50:05 ]  51200 elements loaded
# (49152, 16) (2048, 16)
# [ 2026-03-24 00:50:06 ]  53248 elements loaded
# (51200, 16) (2048, 16)
# [ 2026-03-24 00:50:07 ]  55296 elements loaded
# (53248, 16) (2048, 16)
# [ 2026-03-24 00:50:07 ]  57344 elements loaded
# (55296, 16) (2048, 16)
# [ 2026-03-24 00:50:08 ]  59392 elements loaded
# (57344, 16) (2048, 16)
# [ 2026-03-24 00:50:09 ]  61440 elements loaded
# (59392, 16) (2048, 16)
# [ 2026-03-24 00:50:10 ]  63488 elements loaded
# (61440, 16) (2048, 16)
# [ 2026-03-24 00:50:10 ]  65536 elements loaded
# (63488, 16) (2048, 16)
# [ 2026-03-24 00:50:11 ]  67584 elements loaded
# (65536, 16) (2048, 16)
# [ 2026-03-24 00:50:12 ]  69632 elements loaded
# (67584, 16) (2048, 16)
# [ 2026-03-24 00:50:13 ]  71680 elements loaded
# (69632, 16) (2048, 16)
# [ 2026-03-24 00:50:14 ]  73728 elements loaded
# (71680, 16) (2048, 16)
# [ 2026-03-24 00:50:14 ]  75776 elements loaded
# (73728, 16) (2048, 16)
# [ 2026-03-24 00:50:15 ]  77824 elements loaded
# (75776, 16) (2048, 16)
# [ 2026-03-24 00:50:16 ]  79872 elements loaded
# (77824, 16) (2048, 16)
# [ 2026-03-24 00:50:17 ]  81920 elements loaded
# (79872, 16) (2048, 16)
# [ 2026-03-24 00:50:18 ]  83968 elements loaded
# (81920, 16) (2048, 16)
# [ 2026-03-24 00:50:18 ]  86016 elements loaded
# (83968, 16) (2048, 16)
# [ 2026-03-24 00:50:19 ]  88064 elements loaded
# (86016, 16) (2048, 16)
# [ 2026-03-24 00:50:20 ]  90112 elements loaded
# (88064, 16) (2048, 16)
# [ 2026-03-24 00:50:21 ]  92160 elements loaded
# (90112, 16) (2048, 16)
# [ 2026-03-24 00:50:22 ]  94208 elements loaded
# (92160, 16) (2048, 16)
# [ 2026-03-24 00:50:22 ]  96256 elements loaded
# (94208, 16) (2048, 16)
# [ 2026-03-24 00:50:23 ]  98304 elements loaded
# (96256, 16) (2048, 16)
# [ 2026-03-24 00:50:24 ]  100352 elements loaded
# (98304, 16) (2048, 16)
# [ 2026-03-24 00:50:25 ]  102400 elements loaded
# (100352, 16) (2048, 16)
# [ 2026-03-24 00:50:25 ]  104448 elements loaded
# (102400, 16) (2048, 16)
# [ 2026-03-24 00:50:26 ]  106496 elements loaded
# (104448, 16) (2048, 16)
# [ 2026-03-24 00:50:27 ]  108544 elements loaded
# (106496, 16) (2048, 16)
# [ 2026-03-24 00:50:28 ]  110592 elements loaded
# (108544, 16) (2048, 16)
# [ 2026-03-24 00:50:29 ]  112640 elements loaded
# (110592, 16) (2048, 16)
# [ 2026-03-24 00:50:29 ]  114688 elements loaded
# (112640, 16) (2048, 16)
# [ 2026-03-24 00:50:30 ]  116736 elements loaded
# (114688, 16) (2048, 16)
# [ 2026-03-24 00:50:31 ]  118784 elements loaded
# (116736, 16) (2048, 16)
# [ 2026-03-24 00:50:32 ]  120832 elements loaded
# (118784, 16) (2048, 16)
# [ 2026-03-24 00:50:33 ]  122880 elements loaded
# (120832, 16) (2048, 16)
# [ 2026-03-24 00:50:33 ]  124928 elements loaded
# (122880, 16) (2048, 16)
# [ 2026-03-24 00:50:34 ]  126976 elements loaded
# (124928, 16) (2048, 16)
# [ 2026-03-24 00:50:35 ]  129024 elements loaded
# (126976, 16) (2048, 16)
# [ 2026-03-24 00:50:36 ]  131072 elements loaded
# (129024, 16) (2048, 16)
# [ 2026-03-24 00:50:37 ]  133120 elements loaded
# (131072, 16) (2048, 16)
# [ 2026-03-24 00:50:37 ]  135168 elements loaded
# (133120, 16) (2048, 16)
# [ 2026-03-24 00:50:38 ]  137216 elements loaded
# (135168, 16) (2048, 16)
# [ 2026-03-24 00:50:39 ]  139264 elements loaded
# (137216, 16) (2048, 16)
# [ 2026-03-24 00:50:40 ]  141312 elements loaded
# (139264, 16) (2048, 16)
# [ 2026-03-24 00:50:40 ]  143360 elements loaded
# (141312, 16) (2048, 16)
# [ 2026-03-24 00:50:41 ]  145408 elements loaded
# (143360, 16) (2048, 16)
# [ 2026-03-24 00:50:42 ]  147456 elements loaded
# (145408, 16) (2048, 16)
# [ 2026-03-24 00:50:43 ]  149504 elements loaded
# (147456, 16) (2048, 16)
# [ 2026-03-24 00:50:44 ]  151552 elements loaded
# (149504, 16) (2048, 16)
# [ 2026-03-24 00:50:44 ]  153600 elements loaded
# (151552, 16) (2048, 16)
# [ 2026-03-24 00:50:45 ]  155648 elements loaded
# (153600, 16) (2048, 16)
# [ 2026-03-24 00:50:46 ]  157696 elements loaded
# (155648, 16) (2048, 16)
# [ 2026-03-24 00:50:47 ]  159744 elements loaded
# (157696, 16) (2048, 16)
# [ 2026-03-24 00:50:48 ]  161792 elements loaded
# (159744, 16) (2048, 16)
# [ 2026-03-24 00:50:48 ]  163840 elements loaded
# (161792, 16) (2048, 16)
# [ 2026-03-24 00:50:49 ]  165888 elements loaded
# (163840, 16) (2048, 16)
# [ 2026-03-24 00:50:50 ]  167936 elements loaded
# (165888, 16) (2048, 16)
# [ 2026-03-24 00:50:51 ]  169984 elements loaded
# (167936, 16) (2048, 16)
# [ 2026-03-24 00:50:52 ]  172032 elements loaded
# (169984, 16) (2048, 16)
# [ 2026-03-24 00:50:52 ]  174080 elements loaded
# (172032, 16) (2048, 16)
# [ 2026-03-24 00:50:53 ]  176128 elements loaded
# (174080, 16) (2048, 16)
# [ 2026-03-24 00:50:54 ]  178176 elements loaded
# (176128, 16) (2048, 16)
# [ 2026-03-24 00:50:55 ]  180224 elements loaded
# (178176, 16) (2048, 16)
# [ 2026-03-24 00:50:56 ]  182272 elements loaded
# (180224, 16) (2048, 16)
# [ 2026-03-24 00:50:56 ]  184320 elements loaded
# (182272, 16) (2048, 16)
# [ 2026-03-24 00:50:57 ]  186368 elements loaded
# (184320, 16) (2048, 16)
# [ 2026-03-24 00:50:58 ]  188416 elements loaded
# (186368, 16) (2048, 16)
# [ 2026-03-24 00:50:59 ]  190464 elements loaded
# (188416, 16) (2048, 16)
# [ 2026-03-24 00:51:00 ]  192512 elements loaded
# (190464, 16) (2048, 16)
# [ 2026-03-24 00:51:00 ]  194560 elements loaded
# (192512, 16) (2048, 16)
# [ 2026-03-24 00:51:01 ]  196608 elements loaded
# (194560, 16) (2048, 16)
# [ 2026-03-24 00:51:02 ]  198656 elements loaded
# (196608, 16) (2048, 16)
# [ 2026-03-24 00:51:03 ]  200704 elements loaded
# (198656, 16) (2048, 16)
# [ 2026-03-24 00:51:03 ]  202752 elements loaded
# (200704, 16) (2048, 16)
# [ 2026-03-24 00:51:04 ]  204800 elements loaded
# (202752, 16) (2048, 16)
# [ 2026-03-24 00:51:05 ]  206848 elements loaded
# (204800, 16) (2048, 16)
# [ 2026-03-24 00:51:06 ]  208896 elements loaded
# (206848, 16) (2048, 16)
# [ 2026-03-24 00:51:07 ]  210944 elements loaded
# (208896, 16) (2048, 16)
# [ 2026-03-24 00:51:07 ]  212992 elements loaded
# (210944, 16) (2048, 16)
# [ 2026-03-24 00:51:08 ]  215040 elements loaded
# (212992, 16) (2048, 16)
# [ 2026-03-24 00:51:09 ]  217088 elements loaded
# (215040, 16) (2048, 16)
# [ 2026-03-24 00:51:10 ]  219136 elements loaded
# (217088, 16) (2048, 16)
# [ 2026-03-24 00:51:11 ]  221184 elements loaded
# (219136, 16) (2048, 16)
# [ 2026-03-24 00:51:11 ]  223232 elements loaded
# (221184, 16) (2048, 16)
# [ 2026-03-24 00:51:12 ]  225280 elements loaded
# (223232, 16) (2048, 16)
# [ 2026-03-24 00:51:13 ]  227328 elements loaded
# (225280, 16) (2048, 16)
# [ 2026-03-24 00:51:14 ]  229376 elements loaded
# (227328, 16) (2048, 16)
# [ 2026-03-24 00:51:15 ]  231424 elements loaded
# (229376, 16) (2048, 16)
# [ 2026-03-24 00:51:15 ]  233472 elements loaded
# (231424, 16) (2048, 16)
# [ 2026-03-24 00:51:16 ]  235520 elements loaded
# (233472, 16) (2048, 16)
# [ 2026-03-24 00:51:17 ]  237568 elements loaded
# (235520, 16) (2048, 16)
# [ 2026-03-24 00:51:18 ]  239616 elements loaded
# (237568, 16) (2048, 16)
# [ 2026-03-24 00:51:19 ]  241664 elements loaded
# (239616, 16) (2048, 16)
# [ 2026-03-24 00:51:19 ]  243712 elements loaded
# (241664, 16) (2048, 16)
# [ 2026-03-24 00:51:20 ]  245760 elements loaded
# (243712, 16) (2048, 16)
# [ 2026-03-24 00:51:21 ]  247808 elements loaded
# (245760, 16) (2048, 16)
# [ 2026-03-24 00:51:22 ]  249856 elements loaded
# (247808, 16) (2048, 16)
# [ 2026-03-24 00:51:23 ]  251904 elements loaded
# (249856, 16) (2048, 16)
# [ 2026-03-24 00:51:23 ]  253952 elements loaded
# (251904, 16) (2048, 16)
# [ 2026-03-24 00:51:24 ]  256000 elements loaded
# (253952, 16) (2048, 16)
# [ 2026-03-24 00:51:25 ]  258048 elements loaded
# (256000, 16) (2048, 16)
# [ 2026-03-24 00:51:26 ]  260096 elements loaded
# (258048, 16) (2048, 16)
# [ 2026-03-24 00:51:26 ]  262144 elements loaded
# (260096, 16) (2048, 16)
# [ 2026-03-24 00:51:27 ]  264192 elements loaded
# (262144, 16) (2048, 16)
# [ 2026-03-24 00:51:28 ]  266240 elements loaded
# (264192, 16) (2048, 16)
# [ 2026-03-24 00:51:29 ]  268288 elements loaded
# (266240, 16) (2048, 16)
# [ 2026-03-24 00:51:30 ]  270336 elements loaded
# (268288, 16) (2048, 16)
# [ 2026-03-24 00:51:30 ]  272384 elements loaded
# (270336, 16) (2048, 16)
# [ 2026-03-24 00:51:31 ]  274432 elements loaded
# (272384, 16) (2048, 16)
# [ 2026-03-24 00:51:32 ]  276480 elements loaded
# (274432, 16) (2048, 16)
# [ 2026-03-24 00:51:33 ]  278528 elements loaded
# (276480, 16) (2048, 16)
# [ 2026-03-24 00:51:34 ]  280576 elements loaded
# (278528, 16) (2048, 16)
# [ 2026-03-24 00:51:34 ]  282624 elements loaded
# (280576, 16) (2048, 16)
# [ 2026-03-24 00:51:35 ]  284672 elements loaded
# (282624, 16) (2048, 16)
# [ 2026-03-24 00:51:36 ]  286720 elements loaded
# (284672, 16) (2048, 16)
# [ 2026-03-24 00:51:37 ]  288768 elements loaded
# (286720, 16) (2048, 16)
# [ 2026-03-24 00:51:38 ]  290816 elements loaded
# (288768, 16) (2048, 16)
# [ 2026-03-24 00:51:38 ]  292864 elements loaded
# (290816, 16) (2048, 16)
# Processed 294568 data records from /data/smurf_data/20260324/1774311158/outputs/1774313367.dat
# Processed a total of 294568 data records

# %% [markdown]
# FYI it's not demo'd here, but there are modes which support distributing the data across multiple files, and there exist much faster tools for reading in the data.

# %% [markdown]
# Samples are accumulated over the flux ramp frame.  To get original data, must divide by the accumulation factor.  That factor is

# %%
S.get_channel_frequency_mhz(band)
# Out:
# 2.4

# %%
accum_factor=(1.e6*S.get_channel_frequency_mhz(band))/(S.get_flux_ramp_freq()*1.e3)
bit_factor=2**(12-S.get_lms_gain(band))*2**(7) # this 

print(f'bit_factor = {bit_factor}')
print(f'accum_factor = {accum_factor}')
# Out:
# bit_factor = 4096
# accum_factor = 64.0

# %% [markdown]
# Kind of weird that that's not an integer ; may want to choose the flux ramp frequency more judiciously in future attempts.

# %%
yoffset=1000
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
for ch in range(len(S.which_on(band))):
    ych=bit_factor*d[ch]/accum_factor
    ymax=np.max(ych)
    ymin=np.min(ych)
    yspan=ymax-ymin
    ymedian=np.median(ych)
    ax1.plot(np.real(ych-ymedian) + yoffset*ch)
    ax1.set_ylabel('Real(IQ)',fontsize=18)
    ax1.set_xlabel('Sample #',fontsize=18)
    ax2.plot(np.imag(ych-ymedian) + yoffset*ch)
    ax2.set_ylabel('Imag(IQ)',fontsize=18)
    ax2.set_xlabel('Sample #',fontsize=18)
    fig.suptitle(data_file,fontsize=16)
    #ax2.plot(np.real(ych-ymedian) + yoffset*ch)

# %% [markdown]
# How do PSDs look?

# %%
for ch in range(len(S.which_on(band))):
    ych=bit_factor*d[ch]/accum_factor
    ymax=np.max(ych)
    ymin=np.min(ych)
    yspan=ymax-ymin
    ymedian=np.median(ych)

    freq, pxx = signal.welch(np.abs(ych-ymedian), nperseg=len(ych)/8, fs=37.5e3)
    plt.loglog(freq, np.sqrt(pxx))
    plt.xlabel('Sample')
    plt.ylabel('/rt.Hz')
